# %% [markdown]
# # 아주대학교 데이터 경진대회 (data science competition)
# # 11월 9일 - 10일
#
# ## 데이터셋
# - Fashion MNIST 다중 분류 모델(Multi class classification), **배점: 100점**
#     - Test data 정확도: 80점 정량 평가, 모델: 20점 정성 평가
# - Skin cancer MNIST 이진 분류 모델(Binary classification of inbalanced data), **배점 10점(optional)**
#     - Test data 정확도: 10점 정량 평가, Negative predictive value를 이용해서 평가 예정
#
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image.png)
#
# $$
# \textrm{NPV}:= \frac{\textrm{True Negative}}{\textrm{True Negative+False Negative}}
# $$
#
# ##  Test 데이터 예측 결과 csv 파일을 코드 파일과 함께 제출
#
# ## 정성 평가 반영 내역
# - Overfitting 막는 방법
#     - Dropout, validation data set
# - 데이터에 대한 구조 파악에 필요한 함수 사용
# - 불균형 데이터(imbalanced data) 처리 방법
# - 기타 학습 진행에 유의미한 방법 적용 여부
#
# # Good luck!
